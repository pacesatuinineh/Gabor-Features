# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gabor-Features/blob/main/K2Resnet_wajahSorongRaya.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB5
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/wajahPBD"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/WajahSorongRaya"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 339
# Folder: Moi2, Image Count: 364
# Folder: Raja Ampat, Image Count: 337
# Folder: Maybrat, Image Count: 360

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(haar_image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 896
# Jumlah data validasi: 224
# Jumlah data test: 280

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = EfficientNetB5(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1120
# Jumlah data validasi: 224
# Jumlah data test: 280

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 80s 630ms/step - accuracy: 0.3709 - loss: 13.4395 - val_accuracy: 0.6893 - val_loss: 12.1584 - learning_rate: 1.0000e-04
# Epoch 2/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.5984 - loss: 12.5258 - val_accuracy: 0.7429 - val_loss: 11.9370 - learning_rate: 1.0000e-04
# Epoch 3/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.6377 - loss: 12.1617 - val_accuracy: 0.7714 - val_loss: 11.6683 - learning_rate: 1.0000e-04
# Epoch 4/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.7207 - loss: 11.7821 - val_accuracy: 0.7714 - val_loss: 11.4439 - learning_rate: 1.0000e-04
# Epoch 5/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.7231 - loss: 11.5817 - val_accuracy: 0.7786 - val_loss: 11.2645 - learning_rate: 1.0000e-04
# Epoch 6/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.7754 - loss: 11.2621 - val_accuracy: 0.8214 - val_loss: 11.0682 - learning_rate: 1.0000e-04
# Epoch 7/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.7386 - loss: 11.1251 - val_accuracy: 0.7536 - val_loss: 11.2112 - learning_rate: 1.0000e-04
# Epoch 8/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 408ms/step - accuracy: 0.7624 - loss: 10.9132 - val_accuracy: 0.7679 - val_loss: 10.9220 - learning_rate: 1.0000e-04
# Epoch 9/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.8011 - loss: 10.5357 - val_accuracy: 0.7893 - val_loss: 10.5378 - learning_rate: 1.0000e-04
# Epoch 10/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.7640 - loss: 10.4189 - val_accuracy: 0.7857 - val_loss: 10.4573 - learning_rate: 1.0000e-04
# Epoch 11/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 374ms/step - accuracy: 0.8037 - loss: 10.1212 - val_accuracy: 0.8071 - val_loss: 10.0668 - learning_rate: 1.0000e-04
# Epoch 12/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.7907 - loss: 9.9567 - val_accuracy: 0.8179 - val_loss: 9.8776 - learning_rate: 1.0000e-04
# Epoch 13/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.8168 - loss: 9.6730 - val_accuracy: 0.7714 - val_loss: 9.9069 - learning_rate: 1.0000e-04
# Epoch 14/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.8022 - loss: 9.5294 - val_accuracy: 0.8321 - val_loss: 9.2897 - learning_rate: 1.0000e-04
# Epoch 15/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.8361 - loss: 9.2265 - val_accuracy: 0.8821 - val_loss: 8.9903 - learning_rate: 1.0000e-04
# Epoch 16/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.8452 - loss: 8.9922 - val_accuracy: 0.8643 - val_loss: 8.8460 - learning_rate: 1.0000e-04
# Epoch 17/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.8501 - loss: 8.7975 - val_accuracy: 0.7893 - val_loss: 8.8835 - learning_rate: 1.0000e-04
# Epoch 18/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 412ms/step - accuracy: 0.8270 - loss: 8.5932 - val_accuracy: 0.8321 - val_loss: 8.5103 - learning_rate: 1.0000e-04
# Epoch 19/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.8825 - loss: 8.2819 - val_accuracy: 0.7929 - val_loss: 8.3979 - learning_rate: 1.0000e-04
# Epoch 20/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.8673 - loss: 8.0578 - val_accuracy: 0.8393 - val_loss: 8.0319 - learning_rate: 1.0000e-04
# Epoch 21/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.8845 - loss: 7.8392 - val_accuracy: 0.8214 - val_loss: 7.9561 - learning_rate: 1.0000e-04
# Epoch 22/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.8805 - loss: 7.6301 - val_accuracy: 0.7964 - val_loss: 7.9021 - learning_rate: 1.0000e-04
# Epoch 23/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.8703 - loss: 7.4591 - val_accuracy: 0.8214 - val_loss: 7.5292 - learning_rate: 1.0000e-04
# Epoch 24/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.8720 - loss: 7.2194 - val_accuracy: 0.7893 - val_loss: 7.5003 - learning_rate: 1.0000e-04
# Epoch 25/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.9061 - loss: 6.9706 - val_accuracy: 0.8500 - val_loss: 6.9766 - learning_rate: 1.0000e-04
# Epoch 26/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.8895 - loss: 6.7946 - val_accuracy: 0.7643 - val_loss: 7.4789 - learning_rate: 1.0000e-04
# Epoch 27/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9118 - loss: 6.5332 - val_accuracy: 0.8429 - val_loss: 6.9677 - learning_rate: 1.0000e-04
# Epoch 28/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.9019 - loss: 6.3661 - val_accuracy: 0.8643 - val_loss: 6.3896 - learning_rate: 1.0000e-04
# Epoch 29/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 374ms/step - accuracy: 0.9214 - loss: 6.1547 - val_accuracy: 0.8179 - val_loss: 6.4261 - learning_rate: 1.0000e-04
# Epoch 30/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.9337 - loss: 5.9110 - val_accuracy: 0.8393 - val_loss: 6.1825 - learning_rate: 1.0000e-04
# Epoch 31/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.9224 - loss: 5.7612 - val_accuracy: 0.8107 - val_loss: 6.0723 - learning_rate: 1.0000e-04
# Epoch 32/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.9330 - loss: 5.5653 - val_accuracy: 0.7929 - val_loss: 5.9622 - learning_rate: 1.0000e-04
# Epoch 33/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.9314 - loss: 5.3840 - val_accuracy: 0.8036 - val_loss: 5.5824 - learning_rate: 1.0000e-04
# Epoch 34/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 403ms/step - accuracy: 0.9282 - loss: 5.2189 - val_accuracy: 0.8429 - val_loss: 5.4582 - learning_rate: 1.0000e-04
# Epoch 35/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.9377 - loss: 5.0165 - val_accuracy: 0.8464 - val_loss: 5.1452 - learning_rate: 1.0000e-04
# Epoch 36/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.9509 - loss: 4.8172 - val_accuracy: 0.8536 - val_loss: 5.1296 - learning_rate: 1.0000e-04
# Epoch 37/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.9436 - loss: 4.6805 - val_accuracy: 0.8857 - val_loss: 4.7724 - learning_rate: 1.0000e-04
# Epoch 38/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9484 - loss: 4.4949 - val_accuracy: 0.8536 - val_loss: 4.6361 - learning_rate: 1.0000e-04
# Epoch 39/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.9477 - loss: 4.3438 - val_accuracy: 0.8429 - val_loss: 4.4659 - learning_rate: 1.0000e-04
# Epoch 40/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.9414 - loss: 4.1927 - val_accuracy: 0.8607 - val_loss: 4.3790 - learning_rate: 1.0000e-04
# Epoch 41/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.9539 - loss: 4.0227 - val_accuracy: 0.8750 - val_loss: 4.1309 - learning_rate: 1.0000e-04
# Epoch 42/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.9420 - loss: 3.8953 - val_accuracy: 0.7821 - val_loss: 4.7875 - learning_rate: 1.0000e-04
# Epoch 43/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 386ms/step - accuracy: 0.9361 - loss: 3.7634 - val_accuracy: 0.8000 - val_loss: 4.2621 - learning_rate: 1.0000e-04
# Epoch 44/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.9486 - loss: 3.6030 - val_accuracy: 0.8321 - val_loss: 4.1075 - learning_rate: 1.0000e-04
# Epoch 45/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.9610 - loss: 3.4412 - val_accuracy: 0.8214 - val_loss: 4.0633 - learning_rate: 1.0000e-04
# Epoch 46/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.9344 - loss: 3.3619 - val_accuracy: 0.7893 - val_loss: 4.1430 - learning_rate: 1.0000e-04
# Epoch 47/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9487 - loss: 3.1987 - val_accuracy: 0.7929 - val_loss: 4.0650 - learning_rate: 1.0000e-04
# Epoch 48/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 388ms/step - accuracy: 0.9684 - loss: 3.0463 - val_accuracy: 0.8464 - val_loss: 3.4957 - learning_rate: 1.0000e-04
# Epoch 49/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9620 - loss: 2.9418 - val_accuracy: 0.8036 - val_loss: 3.6975 - learning_rate: 1.0000e-04
# Epoch 50/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.9607 - loss: 2.8114 - val_accuracy: 0.8500 - val_loss: 3.2567 - learning_rate: 1.0000e-04
# Epoch 51/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.9614 - loss: 2.7222 - val_accuracy: 0.8250 - val_loss: 3.1472 - learning_rate: 1.0000e-04
# Epoch 52/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 392ms/step - accuracy: 0.9653 - loss: 2.5889 - val_accuracy: 0.8357 - val_loss: 3.0935 - learning_rate: 1.0000e-04
# Epoch 53/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9702 - loss: 2.4658 - val_accuracy: 0.8536 - val_loss: 2.9206 - learning_rate: 1.0000e-04
# Epoch 54/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 393ms/step - accuracy: 0.9625 - loss: 2.4007 - val_accuracy: 0.8393 - val_loss: 2.6806 - learning_rate: 1.0000e-04
# Epoch 55/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 375ms/step - accuracy: 0.9665 - loss: 2.2952 - val_accuracy: 0.8536 - val_loss: 2.5946 - learning_rate: 1.0000e-04
# Epoch 56/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.9652 - loss: 2.1932 - val_accuracy: 0.8143 - val_loss: 2.7298 - learning_rate: 1.0000e-04
# Epoch 57/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 380ms/step - accuracy: 0.9717 - loss: 2.0804 - val_accuracy: 0.8429 - val_loss: 2.6282 - learning_rate: 1.0000e-04
# Epoch 58/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 382ms/step - accuracy: 0.9611 - loss: 2.0124 - val_accuracy: 0.8500 - val_loss: 2.2822 - learning_rate: 1.0000e-04
# Epoch 59/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9688 - loss: 1.9186 - val_accuracy: 0.8786 - val_loss: 2.1766 - learning_rate: 1.0000e-04
# Epoch 60/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 408ms/step - accuracy: 0.9745 - loss: 1.8197 - val_accuracy: 0.8679 - val_loss: 2.3070 - learning_rate: 1.0000e-04
# Epoch 61/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.9764 - loss: 1.7424 - val_accuracy: 0.8679 - val_loss: 2.1399 - learning_rate: 1.0000e-04
# Epoch 62/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.9786 - loss: 1.6625 - val_accuracy: 0.8429 - val_loss: 2.0826 - learning_rate: 1.0000e-04
# Epoch 63/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.9664 - loss: 1.6149 - val_accuracy: 0.8393 - val_loss: 2.1653 - learning_rate: 1.0000e-04
# Epoch 64/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9608 - loss: 1.5503 - val_accuracy: 0.8071 - val_loss: 2.0939 - learning_rate: 1.0000e-04
# Epoch 65/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 383ms/step - accuracy: 0.9682 - loss: 1.4701 - val_accuracy: 0.8393 - val_loss: 1.8656 - learning_rate: 1.0000e-04
# Epoch 66/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 407ms/step - accuracy: 0.9713 - loss: 1.4060 - val_accuracy: 0.8679 - val_loss: 1.7799 - learning_rate: 1.0000e-04
# Epoch 67/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 391ms/step - accuracy: 0.9726 - loss: 1.3213 - val_accuracy: 0.8321 - val_loss: 1.8088 - learning_rate: 1.0000e-04
# Epoch 68/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.9759 - loss: 1.2739 - val_accuracy: 0.8750 - val_loss: 1.5769 - learning_rate: 1.0000e-04
# Epoch 69/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 399ms/step - accuracy: 0.9725 - loss: 1.2231 - val_accuracy: 0.8607 - val_loss: 1.5647 - learning_rate: 1.0000e-04
# Epoch 70/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.9769 - loss: 1.1731 - val_accuracy: 0.8393 - val_loss: 1.6408 - learning_rate: 1.0000e-04
# Epoch 71/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 395ms/step - accuracy: 0.9778 - loss: 1.1099 - val_accuracy: 0.8143 - val_loss: 1.6671 - learning_rate: 1.0000e-04
# Epoch 72/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.9735 - loss: 1.0626 - val_accuracy: 0.8000 - val_loss: 1.7999 - learning_rate: 1.0000e-04
# Epoch 73/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9722 - loss: 1.0175 - val_accuracy: 0.8357 - val_loss: 1.6381 - learning_rate: 1.0000e-04
# Epoch 74/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 402ms/step - accuracy: 0.9677 - loss: 0.9865 - val_accuracy: 0.8357 - val_loss: 1.5263 - learning_rate: 1.0000e-04
# Epoch 75/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.9707 - loss: 0.9423 - val_accuracy: 0.8321 - val_loss: 1.5915 - learning_rate: 1.0000e-04
# Epoch 76/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9718 - loss: 0.9083 - val_accuracy: 0.7536 - val_loss: 2.0247 - learning_rate: 1.0000e-04
# Epoch 77/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 15s 409ms/step - accuracy: 0.9784 - loss: 0.8510 - val_accuracy: 0.8071 - val_loss: 1.6280 - learning_rate: 1.0000e-04
# Epoch 78/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 398ms/step - accuracy: 0.9684 - loss: 0.8342 - val_accuracy: 0.8321 - val_loss: 1.3673 - learning_rate: 1.0000e-04
# Epoch 79/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 394ms/step - accuracy: 0.9733 - loss: 0.7792 - val_accuracy: 0.7964 - val_loss: 1.4664 - learning_rate: 1.0000e-04
# Epoch 80/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 404ms/step - accuracy: 0.9787 - loss: 0.7452 - val_accuracy: 0.8143 - val_loss: 1.4824 - learning_rate: 1.0000e-04
# Epoch 81/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.9869 - loss: 0.6902 - val_accuracy: 0.7643 - val_loss: 2.0379 - learning_rate: 1.0000e-04
# Epoch 82/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 379ms/step - accuracy: 0.9710 - loss: 0.6843 - val_accuracy: 0.8036 - val_loss: 1.5698 - learning_rate: 1.0000e-04
# Epoch 83/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.9702 - loss: 0.6709 - val_accuracy: 0.8607 - val_loss: 1.0347 - learning_rate: 1.0000e-04
# Epoch 84/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 384ms/step - accuracy: 0.9788 - loss: 0.6134 - val_accuracy: 0.8571 - val_loss: 1.1057 - learning_rate: 1.0000e-04
# Epoch 85/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.9893 - loss: 0.5755 - val_accuracy: 0.8429 - val_loss: 1.1299 - learning_rate: 1.0000e-04
# Epoch 86/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.9761 - loss: 0.5747 - val_accuracy: 0.8071 - val_loss: 1.2054 - learning_rate: 1.0000e-04
# Epoch 87/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 373ms/step - accuracy: 0.9885 - loss: 0.5390 - val_accuracy: 0.7893 - val_loss: 1.5439 - learning_rate: 1.0000e-04
# Epoch 88/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.9735 - loss: 0.5329 - val_accuracy: 0.8643 - val_loss: 0.8925 - learning_rate: 1.0000e-04
# Epoch 89/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 389ms/step - accuracy: 0.9647 - loss: 0.5454 - val_accuracy: 0.8286 - val_loss: 1.0394 - learning_rate: 1.0000e-04
# Epoch 90/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 407ms/step - accuracy: 0.9723 - loss: 0.4929 - val_accuracy: 0.8321 - val_loss: 1.0032 - learning_rate: 1.0000e-04
# Epoch 91/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 381ms/step - accuracy: 0.9869 - loss: 0.4365 - val_accuracy: 0.8857 - val_loss: 0.8206 - learning_rate: 1.0000e-04
# Epoch 92/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 397ms/step - accuracy: 0.9834 - loss: 0.4307 - val_accuracy: 0.8679 - val_loss: 0.9434 - learning_rate: 1.0000e-04
# Epoch 93/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 390ms/step - accuracy: 0.9794 - loss: 0.4164 - val_accuracy: 0.8536 - val_loss: 0.9570 - learning_rate: 1.0000e-04
# Epoch 94/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 379ms/step - accuracy: 0.9833 - loss: 0.4056 - val_accuracy: 0.8357 - val_loss: 1.0433 - learning_rate: 1.0000e-04
# Epoch 95/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 14s 387ms/step - accuracy: 0.9809 - loss: 0.3816 - val_accuracy: 0.7857 - val_loss: 1.5220 - learning_rate: 1.0000e-04
# Epoch 96/100
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 13s 378ms/step - accuracy: 0.9735 - loss: 0.3790 - val_accuracy: 0.8321 - val_loss: 0.8957 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 7s 484ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.84      0.72      0.77        67
#          Moi2       0.93      0.99      0.96        78
#    Raja Ampat       0.97      0.99      0.98        73
# SorongSelatan       0.77      0.82      0.80        62
#
#      accuracy                           0.89       280
#     macro avg       0.88      0.88      0.88       280
#  weighted avg       0.88      0.89      0.88       280
