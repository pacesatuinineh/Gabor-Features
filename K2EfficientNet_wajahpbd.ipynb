# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gabor-Features/blob/main/K2EfficientNet_wajahpbd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install efficientnet==0.0.3

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
#from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.applications import EfficientNetB0
#from tensorflow.keras.applications import VGG16
#from tensorflow.keras.applications import InceptionV3
#from tensorflow.keras.applications import MobileNetV2
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
#data_path = "/content/drive/MyDrive/wajahPBD"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
import os

def list_folders_and_image_count(data_path):
  """
  Lists subfolders within a directory and counts the number of images in each.

  Args:
    data_path: The path to the main directory.

  Returns:
    A dictionary where keys are folder names and values are image counts.
  """
  folder_info = {}
  for folder_name in os.listdir(data_path):
    folder_path = os.path.join(data_path, folder_name)
    if os.path.isdir(folder_path):
      image_count = 0
      for file_name in os.listdir(folder_path):
        if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
          image_count += 1
      folder_info[folder_name] = image_count
  return folder_info

# Example usage:
data_path = "/content/drive/MyDrive/wajahPBD"
folder_data = list_folders_and_image_count(data_path)

# Print the results:
for folder, count in folder_data.items():
  print(f"Folder: {folder}, Image Count: {count}")
# Out:
# Folder: SorongSelatan, Image Count: 339
# Folder: Moi, Image Count: 392
# Folder: Raja Ampat, Image Count: 347
# Folder: Maybrat, Image Count: 360

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
def apply_haar_wavelet_and_gaussian(image):
    coeffs2 = pywt.dwt2(image, 'haar')
    LL, (LH, HL, HH) = coeffs2
    LL_gaussian = cv2.GaussianBlur(LL, (5, 5), 0)  # Apply Gaussian filter
    return LL_gaussian  # Use the low-frequency component with Gaussian filter

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)

                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)

                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))

                    # Extract HOG features
                    #hog_features = extract_hog_features(image)

                    # Extract Gabor features
                    #gabor_features = extract_gabor_features(image)

                    #Extract Haar + Gaussia
                    #haar_image = apply_haar_wavelet_and_gaussian(image)

                    #Extract Haar + Gabor
                    #combined_features = np.concatenate([haar_image.flatten(), gabor_features])

                    data.append(haar_image)  # Append the processed image

                    #data.append(combined_features)  # Append the processed image

                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
num_images_to_display = 5  # Jumlah gambar yang ingin ditampilkan
sample_images = data[:num_images_to_display]
sample_labels = labels[:num_images_to_display]

# %%
fig, axes = plt.subplots(1, num_images_to_display, figsize=(15, 5))  # Sesuaikan figsize jika perlu
for i, (image, label) in enumerate(zip(sample_images, sample_labels)):
    axes[i].imshow(image.astype(np.uint8), cmap='gray')
    axes[i].axis('off')
    axes[i].set_title(label)  # Menampilkan label sebagai judul di bawah gambar
plt.show()

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
#train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.2, random_state=42)
train_images, test_images, train_labels, test_labels = train_test_split(
    data, labels_encoded, test_size=0.2, random_state=42
)

# Split training data into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    train_images, train_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 919
# Jumlah data validasi: 230
# Jumlah data test: 288

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    #base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)
    base_model = EfficientNetB0(weights='imagenet', include_top=False, input_tensor=input_tensor)  # Ganti ResNet50 dengan EfficientNetB
    #base_model = VGG16(weights='imagenet', include_top=False, input_tensor=input_tensor)
    #base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(299, 299, 3))
    #base_model = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    #x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    #x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.3,
    height_shift_range=0.3,
    shear_range=0.3,
    zoom_range=0.3,
    horizontal_flip=True,
    brightness_range=[0.7, 1.3],
    fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
#train_images, train_labels = load_and_preprocess_images(data_path)
#test_images, test_labels = load_and_preprocess_images(data_path)


# Print the number of samples in each set
#print("Jumlah data train:", len(train_images))
#print("Jumlah data validasi:", len(val_images))
#print("Jumlah data test:", len(test_images))

# %%
# Load and preprocess all images first
all_images, all_labels = load_and_preprocess_images(data_path)

# Split into training and testing, maintaining 20% for testing
train_images, test_images, train_labels, test_labels = train_test_split(
    all_images, all_labels, test_size=0.2, random_state=42
)

# Print the number of samples in each set
print("Jumlah data train:", len(train_images))
print("Jumlah data validasi:", len(val_images))  # val_images remains unchanged
print("Jumlah data test:", len(test_images))
# Out:
# Jumlah data train: 1149
# Jumlah data validasi: 230
# Jumlah data test: 288

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 224, 224, 3))
#   warnings.warn(msg)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 131s 2s/step - accuracy: 0.3126 - loss: 12.7250 - val_accuracy: 0.3611 - val_loss: 11.9398 - learning_rate: 1.0000e-04
# Epoch 2/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.3928 - loss: 12.2169 - val_accuracy: 0.3924 - val_loss: 11.6969 - learning_rate: 1.0000e-04
# Epoch 3/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.4701 - loss: 11.8127 - val_accuracy: 0.4410 - val_loss: 11.4421 - learning_rate: 1.0000e-04
# Epoch 4/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.4547 - loss: 11.6243 - val_accuracy: 0.5000 - val_loss: 11.2006 - learning_rate: 1.0000e-04
# Epoch 5/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.4887 - loss: 11.3403 - val_accuracy: 0.5174 - val_loss: 10.9909 - learning_rate: 1.0000e-04
# Epoch 6/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.4835 - loss: 11.1489 - val_accuracy: 0.5312 - val_loss: 10.8048 - learning_rate: 1.0000e-04
# Epoch 7/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.5462 - loss: 10.8938 - val_accuracy: 0.5278 - val_loss: 10.6421 - learning_rate: 1.0000e-04
# Epoch 8/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.5107 - loss: 10.7117 - val_accuracy: 0.5417 - val_loss: 10.4685 - learning_rate: 1.0000e-04
# Epoch 9/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.5272 - loss: 10.5259 - val_accuracy: 0.5451 - val_loss: 10.2926 - learning_rate: 1.0000e-04
# Epoch 10/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.5226 - loss: 10.4115 - val_accuracy: 0.5451 - val_loss: 10.1396 - learning_rate: 1.0000e-04
# Epoch 11/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 362ms/step - accuracy: 0.5730 - loss: 10.1657 - val_accuracy: 0.5660 - val_loss: 9.9622 - learning_rate: 1.0000e-04
# Epoch 12/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.5711 - loss: 9.9659 - val_accuracy: 0.5243 - val_loss: 9.8289 - learning_rate: 1.0000e-04
# Epoch 13/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.5698 - loss: 9.7920 - val_accuracy: 0.5417 - val_loss: 9.6739 - learning_rate: 1.0000e-04
# Epoch 14/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.6134 - loss: 9.6167 - val_accuracy: 0.5451 - val_loss: 9.5014 - learning_rate: 1.0000e-04
# Epoch 15/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.5710 - loss: 9.4701 - val_accuracy: 0.5868 - val_loss: 9.2993 - learning_rate: 1.0000e-04
# Epoch 16/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.6252 - loss: 9.2436 - val_accuracy: 0.5972 - val_loss: 9.1259 - learning_rate: 1.0000e-04
# Epoch 17/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.6232 - loss: 9.0835 - val_accuracy: 0.5833 - val_loss: 8.9548 - learning_rate: 1.0000e-04
# Epoch 18/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.6220 - loss: 8.9289 - val_accuracy: 0.6319 - val_loss: 8.7502 - learning_rate: 1.0000e-04
# Epoch 19/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.6170 - loss: 8.7476 - val_accuracy: 0.6389 - val_loss: 8.5729 - learning_rate: 1.0000e-04
# Epoch 20/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.6419 - loss: 8.5452 - val_accuracy: 0.6319 - val_loss: 8.4175 - learning_rate: 1.0000e-04
# Epoch 21/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.6587 - loss: 8.3384 - val_accuracy: 0.6285 - val_loss: 8.2758 - learning_rate: 1.0000e-04
# Epoch 22/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.6900 - loss: 8.1706 - val_accuracy: 0.6285 - val_loss: 8.0973 - learning_rate: 1.0000e-04
# Epoch 23/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.6724 - loss: 8.0145 - val_accuracy: 0.6042 - val_loss: 7.9319 - learning_rate: 1.0000e-04
# Epoch 24/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.6922 - loss: 7.8042 - val_accuracy: 0.6354 - val_loss: 7.7632 - learning_rate: 1.0000e-04
# Epoch 25/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.6737 - loss: 7.6740 - val_accuracy: 0.6076 - val_loss: 7.6407 - learning_rate: 1.0000e-04
# Epoch 26/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.6966 - loss: 7.4670 - val_accuracy: 0.6354 - val_loss: 7.4454 - learning_rate: 1.0000e-04
# Epoch 27/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 351ms/step - accuracy: 0.6863 - loss: 7.3057 - val_accuracy: 0.6146 - val_loss: 7.2931 - learning_rate: 1.0000e-04
# Epoch 28/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 14s 373ms/step - accuracy: 0.7382 - loss: 7.0875 - val_accuracy: 0.6458 - val_loss: 7.0904 - learning_rate: 1.0000e-04
# Epoch 29/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.7304 - loss: 6.9338 - val_accuracy: 0.6389 - val_loss: 6.9606 - learning_rate: 1.0000e-04
# Epoch 30/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.7053 - loss: 6.8015 - val_accuracy: 0.6597 - val_loss: 6.7879 - learning_rate: 1.0000e-04
# Epoch 31/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 353ms/step - accuracy: 0.7077 - loss: 6.6494 - val_accuracy: 0.6458 - val_loss: 6.6621 - learning_rate: 1.0000e-04
# Epoch 32/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 362ms/step - accuracy: 0.7445 - loss: 6.4328 - val_accuracy: 0.6875 - val_loss: 6.4651 - learning_rate: 1.0000e-04
# Epoch 33/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.7471 - loss: 6.3003 - val_accuracy: 0.6562 - val_loss: 6.3700 - learning_rate: 1.0000e-04
# Epoch 34/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.7742 - loss: 6.1244 - val_accuracy: 0.6215 - val_loss: 6.2226 - learning_rate: 1.0000e-04
# Epoch 35/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.7523 - loss: 5.9611 - val_accuracy: 0.6181 - val_loss: 6.1213 - learning_rate: 1.0000e-04
# Epoch 36/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.7679 - loss: 5.8054 - val_accuracy: 0.6389 - val_loss: 5.9359 - learning_rate: 1.0000e-04
# Epoch 37/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 352ms/step - accuracy: 0.7974 - loss: 5.5918 - val_accuracy: 0.6597 - val_loss: 5.8186 - learning_rate: 1.0000e-04
# Epoch 38/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.7955 - loss: 5.4720 - val_accuracy: 0.6389 - val_loss: 5.7397 - learning_rate: 1.0000e-04
# Epoch 39/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.7763 - loss: 5.3578 - val_accuracy: 0.6771 - val_loss: 5.5763 - learning_rate: 1.0000e-04
# Epoch 40/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.8040 - loss: 5.1717 - val_accuracy: 0.6736 - val_loss: 5.3768 - learning_rate: 1.0000e-04
# Epoch 41/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.7881 - loss: 5.0743 - val_accuracy: 0.7083 - val_loss: 5.2205 - learning_rate: 1.0000e-04
# Epoch 42/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.8134 - loss: 4.8691 - val_accuracy: 0.6771 - val_loss: 5.1615 - learning_rate: 1.0000e-04
# Epoch 43/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.8246 - loss: 4.7323 - val_accuracy: 0.6736 - val_loss: 5.1535 - learning_rate: 1.0000e-04
# Epoch 44/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.8121 - loss: 4.6281 - val_accuracy: 0.6562 - val_loss: 5.0769 - learning_rate: 1.0000e-04
# Epoch 45/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.8400 - loss: 4.4645 - val_accuracy: 0.6771 - val_loss: 4.8926 - learning_rate: 1.0000e-04
# Epoch 46/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.8348 - loss: 4.3255 - val_accuracy: 0.6389 - val_loss: 4.8994 - learning_rate: 1.0000e-04
# Epoch 47/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.8550 - loss: 4.1952 - val_accuracy: 0.6562 - val_loss: 4.7667 - learning_rate: 1.0000e-04
# Epoch 48/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.8396 - loss: 4.0986 - val_accuracy: 0.6910 - val_loss: 4.5136 - learning_rate: 1.0000e-04
# Epoch 49/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.8487 - loss: 3.9398 - val_accuracy: 0.7049 - val_loss: 4.3429 - learning_rate: 1.0000e-04
# Epoch 50/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.8471 - loss: 3.8270 - val_accuracy: 0.7083 - val_loss: 4.2481 - learning_rate: 1.0000e-04
# Epoch 51/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.8877 - loss: 3.6738 - val_accuracy: 0.7222 - val_loss: 4.1478 - learning_rate: 1.0000e-04
# Epoch 52/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.8443 - loss: 3.6428 - val_accuracy: 0.6771 - val_loss: 4.1622 - learning_rate: 1.0000e-04
# Epoch 53/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.8884 - loss: 3.4634 - val_accuracy: 0.7049 - val_loss: 3.9562 - learning_rate: 1.0000e-04
# Epoch 54/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 362ms/step - accuracy: 0.8792 - loss: 3.3677 - val_accuracy: 0.6597 - val_loss: 4.0109 - learning_rate: 1.0000e-04
# Epoch 55/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.8764 - loss: 3.2754 - val_accuracy: 0.7118 - val_loss: 3.7888 - learning_rate: 1.0000e-04
# Epoch 56/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.8694 - loss: 3.2054 - val_accuracy: 0.6944 - val_loss: 3.6878 - learning_rate: 1.0000e-04
# Epoch 57/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.8732 - loss: 3.1044 - val_accuracy: 0.6979 - val_loss: 3.6760 - learning_rate: 1.0000e-04
# Epoch 58/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.8907 - loss: 2.9614 - val_accuracy: 0.6597 - val_loss: 3.7315 - learning_rate: 1.0000e-04
# Epoch 59/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.8991 - loss: 2.8607 - val_accuracy: 0.6910 - val_loss: 3.4948 - learning_rate: 1.0000e-04
# Epoch 60/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.8808 - loss: 2.8070 - val_accuracy: 0.7014 - val_loss: 3.4722 - learning_rate: 1.0000e-04
# Epoch 61/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.8880 - loss: 2.6973 - val_accuracy: 0.6875 - val_loss: 3.4075 - learning_rate: 1.0000e-04
# Epoch 62/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.9198 - loss: 2.5496 - val_accuracy: 0.6528 - val_loss: 3.4767 - learning_rate: 1.0000e-04
# Epoch 63/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.8965 - loss: 2.5244 - val_accuracy: 0.7014 - val_loss: 3.2915 - learning_rate: 1.0000e-04
# Epoch 64/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.9042 - loss: 2.4314 - val_accuracy: 0.7118 - val_loss: 3.1136 - learning_rate: 1.0000e-04
# Epoch 65/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.9215 - loss: 2.3185 - val_accuracy: 0.7188 - val_loss: 3.0374 - learning_rate: 1.0000e-04
# Epoch 66/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 365ms/step - accuracy: 0.9033 - loss: 2.2819 - val_accuracy: 0.7118 - val_loss: 3.0320 - learning_rate: 1.0000e-04
# Epoch 67/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 361ms/step - accuracy: 0.9228 - loss: 2.1721 - val_accuracy: 0.7292 - val_loss: 2.9256 - learning_rate: 1.0000e-04
# Epoch 68/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.8885 - loss: 2.1730 - val_accuracy: 0.6806 - val_loss: 2.9321 - learning_rate: 1.0000e-04
# Epoch 69/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.9111 - loss: 2.0374 - val_accuracy: 0.7153 - val_loss: 2.7816 - learning_rate: 1.0000e-04
# Epoch 70/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.9177 - loss: 1.9815 - val_accuracy: 0.6806 - val_loss: 2.8967 - learning_rate: 1.0000e-04
# Epoch 71/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 363ms/step - accuracy: 0.9351 - loss: 1.8701 - val_accuracy: 0.7257 - val_loss: 2.6230 - learning_rate: 1.0000e-04
# Epoch 72/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.9296 - loss: 1.8167 - val_accuracy: 0.7153 - val_loss: 2.6199 - learning_rate: 1.0000e-04
# Epoch 73/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.9379 - loss: 1.7506 - val_accuracy: 0.6528 - val_loss: 2.9599 - learning_rate: 1.0000e-04
# Epoch 74/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.9327 - loss: 1.7039 - val_accuracy: 0.7188 - val_loss: 2.5867 - learning_rate: 1.0000e-04
# Epoch 75/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 353ms/step - accuracy: 0.9278 - loss: 1.6487 - val_accuracy: 0.6736 - val_loss: 2.7238 - learning_rate: 1.0000e-04
# Epoch 76/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.9497 - loss: 1.5684 - val_accuracy: 0.6910 - val_loss: 2.6016 - learning_rate: 1.0000e-04
# Epoch 77/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 366ms/step - accuracy: 0.9199 - loss: 1.5645 - val_accuracy: 0.7083 - val_loss: 2.4606 - learning_rate: 1.0000e-04
# Epoch 78/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.9453 - loss: 1.4697 - val_accuracy: 0.6840 - val_loss: 2.4131 - learning_rate: 1.0000e-04
# Epoch 79/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.9373 - loss: 1.4358 - val_accuracy: 0.6424 - val_loss: 2.5531 - learning_rate: 1.0000e-04
# Epoch 80/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.9396 - loss: 1.3513 - val_accuracy: 0.6944 - val_loss: 2.4884 - learning_rate: 1.0000e-04
# Epoch 81/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.9342 - loss: 1.3648 - val_accuracy: 0.6979 - val_loss: 2.3044 - learning_rate: 1.0000e-04
# Epoch 82/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.9304 - loss: 1.3077 - val_accuracy: 0.6806 - val_loss: 2.2325 - learning_rate: 1.0000e-04
# Epoch 83/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.9415 - loss: 1.2606 - val_accuracy: 0.7222 - val_loss: 2.1387 - learning_rate: 1.0000e-04
# Epoch 84/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.9504 - loss: 1.1823 - val_accuracy: 0.7222 - val_loss: 2.2046 - learning_rate: 1.0000e-04
# Epoch 85/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 353ms/step - accuracy: 0.9312 - loss: 1.1906 - val_accuracy: 0.6944 - val_loss: 2.1863 - learning_rate: 1.0000e-04
# Epoch 86/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 364ms/step - accuracy: 0.9441 - loss: 1.1175 - val_accuracy: 0.7292 - val_loss: 2.0910 - learning_rate: 1.0000e-04
# Epoch 87/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 353ms/step - accuracy: 0.9503 - loss: 1.0583 - val_accuracy: 0.6840 - val_loss: 2.2423 - learning_rate: 1.0000e-04
# Epoch 88/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 356ms/step - accuracy: 0.9385 - loss: 1.0691 - val_accuracy: 0.6771 - val_loss: 2.1034 - learning_rate: 1.0000e-04
# Epoch 89/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 362ms/step - accuracy: 0.9441 - loss: 0.9984 - val_accuracy: 0.7083 - val_loss: 2.0412 - learning_rate: 1.0000e-04
# Epoch 90/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 359ms/step - accuracy: 0.9452 - loss: 0.9573 - val_accuracy: 0.7222 - val_loss: 1.8591 - learning_rate: 1.0000e-04
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 357ms/step - accuracy: 0.9511 - loss: 0.9180 - val_accuracy: 0.7188 - val_loss: 1.9403 - learning_rate: 1.0000e-04
# Epoch 92/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 349ms/step - accuracy: 0.9604 - loss: 0.8777 - val_accuracy: 0.6944 - val_loss: 1.9722 - learning_rate: 1.0000e-04
# Epoch 93/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.9585 - loss: 0.8556 - val_accuracy: 0.7188 - val_loss: 1.7565 - learning_rate: 1.0000e-04
# Epoch 94/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 360ms/step - accuracy: 0.9485 - loss: 0.8689 - val_accuracy: 0.7292 - val_loss: 1.7605 - learning_rate: 1.0000e-04
# Epoch 95/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 358ms/step - accuracy: 0.9700 - loss: 0.7861 - val_accuracy: 0.7049 - val_loss: 1.9442 - learning_rate: 1.0000e-04
# Epoch 96/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 354ms/step - accuracy: 0.9577 - loss: 0.7563 - val_accuracy: 0.7153 - val_loss: 1.9191 - learning_rate: 1.0000e-04
# Epoch 97/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 353ms/step - accuracy: 0.9447 - loss: 0.7548 - val_accuracy: 0.7014 - val_loss: 1.9074 - learning_rate: 1.0000e-04
# Epoch 98/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 13s 355ms/step - accuracy: 0.9627 - loss: 0.6957 - val_accuracy: 0.6944 - val_loss: 1.8492 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(32, 224, 224, 3))
#   warnings.warn(msg)
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step
#                precision    recall  f1-score   support
#
#       Maybrat       0.68      0.66      0.67        77
#           Moi       0.64      0.59      0.61        73
#    Raja Ampat       1.00      1.00      1.00        73
# SorongSelatan       0.55      0.62      0.58        65
#
#      accuracy                           0.72       288
#     macro avg       0.72      0.72      0.72       288
#  weighted avg       0.72      0.72      0.72       288
