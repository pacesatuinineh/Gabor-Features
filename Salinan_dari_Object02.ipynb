# %% [markdown]
# <a href="https://colab.research.google.com/github/pacesatuinineh/Gabor-Features/blob/main/Salinan_dari_Object02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
import os
import pandas as pd
from skimage.feature import hog
from skimage.color import rgb2gray
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D, BatchNormalization, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.utils import to_categorical
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Paths
data_path = "/content/drive/MyDrive/modifdataset"  # Adjust the path to where 'papua-1' and 'papua-2' are located

# %%
# Constants
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 100

# %%
# Preprocessing Function
def preprocess_image(image):
    # Resize image
    image = cv2.resize(image, IMAGE_SIZE)
    # Histogram equalization
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    image = cv2.equalizeHist(image)
    # Apply noise reduction
    image = cv2.fastNlMeansDenoising(image, h=10)
    # Convert back to RGB
    return cv2.cvtColor(image, cv2.COLOR_GRAY2RGB)

# %%
# Function to apply Haar wavelet transformation
def apply_haar_wavelet(image):
    I = image.astype(float)
    m, n = I.shape[:2]
    if m % 2 != 0:
        m -= 1
    if n % 2 != 0:
        n -= 1
    I = I[:m, :n]

    LL = np.zeros((m // 2, n // 2))
    for i in range(0, m, 2):
        for j in range(0, n, 2):
            Ixy = I[i:i + 2, j:j + 2]
            LL[i // 2, j // 2] = np.mean(Ixy)
    return LL

# %%
# Function to extract HOG features
def extract_hog_features(image):
    if len(image.shape) == 3:
        image = rgb2gray(image)
    features, _ = hog(image, pixels_per_cell=(8, 8), cells_per_block=(2, 2), visualize=True)
    return features

# %%
def load_data(path):
    data = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    # Preprocess image
                    image = preprocess_image(image)
                    # Apply Haar wavelet
                    haar_image = apply_haar_wavelet(image)
                    # Resize the image to 224x224 for ResNet50
                    haar_image = cv2.resize(haar_image, (224, 224))
                    # Extract HOG features
                    hog_features = extract_hog_features(image)
                    data.append(haar_image)  # Append the processed image
                    labels.append(folder)

    return np.array(data), np.array(labels)

# %%
# Load dataset
data, labels = load_data(data_path)

# %%
# Encode labels
encoder = LabelEncoder()
labels_encoded = encoder.fit_transform(labels)

# %%
# Split into training and testing
from sklearn.model_selection import train_test_split
train_data, test_data, train_labels, test_labels = train_test_split(data, labels_encoded, test_size=0.3, random_state=42)

# %%
# Class weights
class_weights = compute_class_weight('balanced', classes=np.unique(train_labels), y=train_labels)
class_weight_dict = dict(enumerate(class_weights))

# %%
# Define CNN model with pretrained ResNet50
def build_model():
    input_tensor = Input(shape=(224, 224, 3))
    base_model = ResNet50(weights='imagenet', include_top=False, input_tensor=input_tensor)

    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)
    x = Dense(512, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)  # Tambahan lapisan
    x = Dropout(0.5)(x)
    x = Dense(256, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = Dropout(0.5)(x)
    predictions = Dense(len(encoder.classes_), activation='softmax')(x)

    model = Model(inputs=base_model.input, outputs=predictions)

    # Unfreeze the top layers of the model
    for layer in base_model.layers[-50:]:
        layer.trainable = True

    # Compile model
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4), loss='categorical_crossentropy', metrics=['accuracy'])
    return model

model = build_model()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Data augmentation
train_datagen = ImageDataGenerator(
    #rotation_range=40,
    width_shift_range=0.3,
    height_shift_range=0.3,
    #shear_range=0.5,
    #zoom_range=0.5,
    #horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    #fill_mode='nearest'
)

# %%
test_datagen = ImageDataGenerator()

# %%
# Load and preprocess images for CNN
def load_and_preprocess_images(path):
    images = []
    labels = []
    for folder in os.listdir(path):
        folder_path = os.path.join(path, folder)
        if os.path.isdir(folder_path):
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path, file)
                image = cv2.imread(file_path)
                if image is not None:
                    image = preprocess_image(image)
                    images.append(image)
                    labels.append(folder)
    return np.array(images), np.array(labels)

# %%
train_images, train_labels = load_and_preprocess_images(data_path)
test_images, test_labels = load_and_preprocess_images(data_path)

# %%
# Encode labels
train_labels_encoded = encoder.fit_transform(train_labels)
test_labels_encoded = encoder.transform(test_labels)

train_labels_categorical = to_categorical(train_labels_encoded)
test_labels_categorical = to_categorical(test_labels_encoded)

# Callbacks
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=1e-5)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# %%
# Fit the model
history = model.fit(
    train_datagen.flow(train_images, train_labels_categorical, batch_size=BATCH_SIZE),
    epochs=EPOCHS,
    validation_data=test_datagen.flow(test_images, test_labels_categorical, batch_size=BATCH_SIZE),
    callbacks=[reduce_lr, early_stopping],
    class_weight=class_weight_dict
)
# Out:
# Epoch 1/100
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.2139 - loss: 16.0028 - val_accuracy: 0.2519 - val_loss: 14.7790 - learning_rate: 1.0000e-04
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 67s 562ms/step - accuracy: 0.2103 - loss: 15.4559 - val_accuracy: 0.2352 - val_loss: 14.5969 - learning_rate: 1.0000e-04
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 559ms/step - accuracy: 0.2370 - loss: 15.1111 - val_accuracy: 0.1947 - val_loss: 14.5568 - learning_rate: 1.0000e-04
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 581ms/step - accuracy: 0.2389 - loss: 14.8202 - val_accuracy: 0.2590 - val_loss: 14.2874 - learning_rate: 1.0000e-04
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 565ms/step - accuracy: 0.2365 - loss: 14.5926 - val_accuracy: 0.2802 - val_loss: 14.1507 - learning_rate: 1.0000e-04
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 586ms/step - accuracy: 0.2451 - loss: 14.2553 - val_accuracy: 0.2275 - val_loss: 13.9167 - learning_rate: 1.0000e-04
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 593ms/step - accuracy: 0.2739 - loss: 14.0109 - val_accuracy: 0.3001 - val_loss: 14.2351 - learning_rate: 1.0000e-04
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 601ms/step - accuracy: 0.2890 - loss: 13.7349 - val_accuracy: 0.3528 - val_loss: 13.3854 - learning_rate: 1.0000e-04
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 595ms/step - accuracy: 0.2955 - loss: 13.5409 - val_accuracy: 0.3438 - val_loss: 13.3716 - learning_rate: 1.0000e-04
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 618ms/step - accuracy: 0.3168 - loss: 13.2731 - val_accuracy: 0.3593 - val_loss: 13.0300 - learning_rate: 1.0000e-04
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 590ms/step - accuracy: 0.3202 - loss: 13.0531 - val_accuracy: 0.4087 - val_loss: 12.7354 - learning_rate: 1.0000e-04
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 584ms/step - accuracy: 0.3332 - loss: 12.8356 - val_accuracy: 0.3567 - val_loss: 12.7022 - learning_rate: 1.0000e-04
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 582ms/step - accuracy: 0.3380 - loss: 12.5765 - val_accuracy: 0.4383 - val_loss: 12.2192 - learning_rate: 1.0000e-04
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 603ms/step - accuracy: 0.3918 - loss: 12.2810 - val_accuracy: 0.4756 - val_loss: 12.0404 - learning_rate: 1.0000e-04
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 550ms/step - accuracy: 0.3821 - loss: 12.0696 - val_accuracy: 0.4781 - val_loss: 11.8066 - learning_rate: 1.0000e-04
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 555ms/step - accuracy: 0.4170 - loss: 11.7856 - val_accuracy: 0.4589 - val_loss: 11.5873 - learning_rate: 1.0000e-04
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 593ms/step - accuracy: 0.4388 - loss: 11.5658 - val_accuracy: 0.5064 - val_loss: 11.3952 - learning_rate: 1.0000e-04
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 583ms/step - accuracy: 0.4569 - loss: 11.3467 - val_accuracy: 0.5790 - val_loss: 11.0193 - learning_rate: 1.0000e-04
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 573ms/step - accuracy: 0.4933 - loss: 11.1042 - val_accuracy: 0.5219 - val_loss: 10.8521 - learning_rate: 1.0000e-04
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 551ms/step - accuracy: 0.5000 - loss: 10.8415 - val_accuracy: 0.5161 - val_loss: 10.9026 - learning_rate: 1.0000e-04
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 562ms/step - accuracy: 0.5201 - loss: 10.5951 - val_accuracy: 0.6086 - val_loss: 10.2677 - learning_rate: 1.0000e-04
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 589ms/step - accuracy: 0.5490 - loss: 10.3302 - val_accuracy: 0.5668 - val_loss: 10.1872 - learning_rate: 1.0000e-04
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 580ms/step - accuracy: 0.5448 - loss: 10.1194 - val_accuracy: 0.6375 - val_loss: 9.8450 - learning_rate: 1.0000e-04
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 588ms/step - accuracy: 0.5632 - loss: 9.8383 - val_accuracy: 0.5199 - val_loss: 10.0156 - learning_rate: 1.0000e-04
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 592ms/step - accuracy: 0.5852 - loss: 9.6020 - val_accuracy: 0.6150 - val_loss: 9.4942 - learning_rate: 1.0000e-04
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 33s 574ms/step - accuracy: 0.6080 - loss: 9.3505 - val_accuracy: 0.6356 - val_loss: 9.3130 - learning_rate: 1.0000e-04
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 574ms/step - accuracy: 0.6043 - loss: 9.1436 - val_accuracy: 0.6517 - val_loss: 8.9082 - learning_rate: 1.0000e-04
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 563ms/step - accuracy: 0.6549 - loss: 8.8267 - val_accuracy: 0.6607 - val_loss: 8.7348 - learning_rate: 1.0000e-04
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 578ms/step - accuracy: 0.6843 - loss: 8.5684 - val_accuracy: 0.6729 - val_loss: 8.4991 - learning_rate: 1.0000e-04
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 558ms/step - accuracy: 0.6571 - loss: 8.3828 - val_accuracy: 0.6388 - val_loss: 8.3241 - learning_rate: 1.0000e-04
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 549ms/step - accuracy: 0.6794 - loss: 8.1723 - val_accuracy: 0.7487 - val_loss: 7.9441 - learning_rate: 1.0000e-04
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 560ms/step - accuracy: 0.7045 - loss: 7.8926 - val_accuracy: 0.7532 - val_loss: 7.7243 - learning_rate: 1.0000e-04
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 553ms/step - accuracy: 0.7143 - loss: 7.7065 - val_accuracy: 0.7487 - val_loss: 7.5403 - learning_rate: 1.0000e-04
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 573ms/step - accuracy: 0.7378 - loss: 7.4386 - val_accuracy: 0.6517 - val_loss: 7.5253 - learning_rate: 1.0000e-04
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 569ms/step - accuracy: 0.7145 - loss: 7.3298 - val_accuracy: 0.7198 - val_loss: 7.2059 - learning_rate: 1.0000e-04
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 582ms/step - accuracy: 0.7832 - loss: 6.9985 - val_accuracy: 0.6941 - val_loss: 7.0564 - learning_rate: 1.0000e-04
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 588ms/step - accuracy: 0.7969 - loss: 6.7691 - val_accuracy: 0.8753 - val_loss: 6.4619 - learning_rate: 1.0000e-04
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 588ms/step - accuracy: 0.8251 - loss: 6.5559 - val_accuracy: 0.8143 - val_loss: 6.4373 - learning_rate: 1.0000e-04
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 577ms/step - accuracy: 0.8219 - loss: 6.3534 - val_accuracy: 0.7256 - val_loss: 6.5101 - learning_rate: 1.0000e-04
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 584ms/step - accuracy: 0.8383 - loss: 6.1630 - val_accuracy: 0.8895 - val_loss: 5.8702 - learning_rate: 1.0000e-04
# Epoch 41/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 576ms/step - accuracy: 0.8483 - loss: 5.9339 - val_accuracy: 0.7744 - val_loss: 6.0718 - learning_rate: 1.0000e-04
# Epoch 42/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 561ms/step - accuracy: 0.8759 - loss: 5.6930 - val_accuracy: 0.6350 - val_loss: 6.5106 - learning_rate: 1.0000e-04
# Epoch 43/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 553ms/step - accuracy: 0.8436 - loss: 5.6302 - val_accuracy: 0.8207 - val_loss: 5.5628 - learning_rate: 1.0000e-04
# Epoch 44/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 556ms/step - accuracy: 0.8690 - loss: 5.3952 - val_accuracy: 0.8888 - val_loss: 5.1842 - learning_rate: 1.0000e-04
# Epoch 45/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 560ms/step - accuracy: 0.8994 - loss: 5.1255 - val_accuracy: 0.8882 - val_loss: 5.0688 - learning_rate: 1.0000e-04
# Epoch 46/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 572ms/step - accuracy: 0.8899 - loss: 4.9963 - val_accuracy: 0.7545 - val_loss: 5.3421 - learning_rate: 1.0000e-04
# Epoch 47/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 585ms/step - accuracy: 0.8866 - loss: 4.8817 - val_accuracy: 0.8181 - val_loss: 4.8888 - learning_rate: 1.0000e-04
# Epoch 48/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 593ms/step - accuracy: 0.9255 - loss: 4.6094 - val_accuracy: 0.7828 - val_loss: 4.9269 - learning_rate: 1.0000e-04
# Epoch 49/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 33s 615ms/step - accuracy: 0.9095 - loss: 4.4810 - val_accuracy: 0.5090 - val_loss: 6.6204 - learning_rate: 1.0000e-04
# Epoch 50/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 603ms/step - accuracy: 0.9257 - loss: 4.2605 - val_accuracy: 0.9608 - val_loss: 4.0673 - learning_rate: 1.0000e-04
# Epoch 51/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 601ms/step - accuracy: 0.9341 - loss: 4.1102 - val_accuracy: 0.9165 - val_loss: 4.0393 - learning_rate: 1.0000e-04
# Epoch 52/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 33s 584ms/step - accuracy: 0.9468 - loss: 3.9478 - val_accuracy: 0.8914 - val_loss: 3.9656 - learning_rate: 1.0000e-04
# Epoch 53/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 574ms/step - accuracy: 0.9416 - loss: 3.8185 - val_accuracy: 0.8779 - val_loss: 3.9245 - learning_rate: 1.0000e-04
# Epoch 54/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 587ms/step - accuracy: 0.9458 - loss: 3.6508 - val_accuracy: 0.7853 - val_loss: 4.0541 - learning_rate: 1.0000e-04
# Epoch 55/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 592ms/step - accuracy: 0.9403 - loss: 3.5534 - val_accuracy: 0.9287 - val_loss: 3.4646 - learning_rate: 1.0000e-04
# Epoch 56/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 607ms/step - accuracy: 0.9402 - loss: 3.4323 - val_accuracy: 0.9537 - val_loss: 3.2824 - learning_rate: 1.0000e-04
# Epoch 57/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 601ms/step - accuracy: 0.9563 - loss: 3.2319 - val_accuracy: 0.7847 - val_loss: 3.5914 - learning_rate: 1.0000e-04
# Epoch 58/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 585ms/step - accuracy: 0.9561 - loss: 3.1406 - val_accuracy: 0.9717 - val_loss: 2.9651 - learning_rate: 1.0000e-04
# Epoch 59/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 566ms/step - accuracy: 0.9587 - loss: 2.9632 - val_accuracy: 0.9524 - val_loss: 2.9037 - learning_rate: 1.0000e-04
# Epoch 60/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 568ms/step - accuracy: 0.9576 - loss: 2.8625 - val_accuracy: 0.8644 - val_loss: 3.0409 - learning_rate: 1.0000e-04
# Epoch 61/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 581ms/step - accuracy: 0.9450 - loss: 2.8399 - val_accuracy: 0.8914 - val_loss: 2.8394 - learning_rate: 1.0000e-04
# Epoch 62/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 604ms/step - accuracy: 0.9565 - loss: 2.6491 - val_accuracy: 0.9042 - val_loss: 2.7168 - learning_rate: 1.0000e-04
# Epoch 63/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 604ms/step - accuracy: 0.9655 - loss: 2.5130 - val_accuracy: 0.9030 - val_loss: 2.6397 - learning_rate: 1.0000e-04
# Epoch 64/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 584ms/step - accuracy: 0.9594 - loss: 2.4190 - val_accuracy: 0.9531 - val_loss: 2.3533 - learning_rate: 1.0000e-04
# Epoch 65/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 569ms/step - accuracy: 0.9556 - loss: 2.3595 - val_accuracy: 0.8329 - val_loss: 2.6847 - learning_rate: 1.0000e-04
# Epoch 66/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 572ms/step - accuracy: 0.9599 - loss: 2.2384 - val_accuracy: 0.9364 - val_loss: 2.2405 - learning_rate: 1.0000e-04
# Epoch 67/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 576ms/step - accuracy: 0.9203 - loss: 2.2762 - val_accuracy: 0.7905 - val_loss: 2.7667 - learning_rate: 1.0000e-04
# Epoch 68/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 578ms/step - accuracy: 0.9737 - loss: 2.0219 - val_accuracy: 0.9672 - val_loss: 1.9626 - learning_rate: 1.0000e-04
# Epoch 69/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 586ms/step - accuracy: 0.9809 - loss: 1.9338 - val_accuracy: 0.9312 - val_loss: 1.9827 - learning_rate: 1.0000e-04
# Epoch 70/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 599ms/step - accuracy: 0.9607 - loss: 1.8808 - val_accuracy: 0.8760 - val_loss: 2.0630 - learning_rate: 1.0000e-04
# Epoch 71/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 597ms/step - accuracy: 0.9648 - loss: 1.7772 - val_accuracy: 0.7969 - val_loss: 2.3194 - learning_rate: 1.0000e-04
# Epoch 72/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 600ms/step - accuracy: 0.9559 - loss: 1.7495 - val_accuracy: 0.8201 - val_loss: 2.0458 - learning_rate: 1.0000e-04
# Epoch 73/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 33s 583ms/step - accuracy: 0.9656 - loss: 1.6406 - val_accuracy: 0.9602 - val_loss: 1.5930 - learning_rate: 1.0000e-04
# Epoch 74/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 574ms/step - accuracy: 0.9762 - loss: 1.5294 - val_accuracy: 0.9531 - val_loss: 1.5321 - learning_rate: 1.0000e-04
# Epoch 75/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 589ms/step - accuracy: 0.9721 - loss: 1.4920 - val_accuracy: 0.9492 - val_loss: 1.4950 - learning_rate: 1.0000e-04
# Epoch 76/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 597ms/step - accuracy: 0.9797 - loss: 1.4040 - val_accuracy: 0.9454 - val_loss: 1.4503 - learning_rate: 1.0000e-04
# Epoch 77/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 608ms/step - accuracy: 0.9828 - loss: 1.3322 - val_accuracy: 0.9692 - val_loss: 1.3003 - learning_rate: 1.0000e-04
# Epoch 78/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 602ms/step - accuracy: 0.9642 - loss: 1.3323 - val_accuracy: 0.8599 - val_loss: 1.7036 - learning_rate: 1.0000e-04
# Epoch 79/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 33s 611ms/step - accuracy: 0.9622 - loss: 1.2779 - val_accuracy: 0.9377 - val_loss: 1.2842 - learning_rate: 1.0000e-04
# Epoch 80/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 616ms/step - accuracy: 0.9601 - loss: 1.1987 - val_accuracy: 0.9576 - val_loss: 1.1762 - learning_rate: 1.0000e-04
# Epoch 81/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 613ms/step - accuracy: 0.9849 - loss: 1.1098 - val_accuracy: 0.9666 - val_loss: 1.0921 - learning_rate: 1.0000e-04
# Epoch 82/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 604ms/step - accuracy: 0.9780 - loss: 1.0768 - val_accuracy: 0.7776 - val_loss: 1.7130 - learning_rate: 1.0000e-04
# Epoch 83/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 614ms/step - accuracy: 0.9742 - loss: 1.0347 - val_accuracy: 0.9357 - val_loss: 1.1110 - learning_rate: 1.0000e-04
# Epoch 84/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 607ms/step - accuracy: 0.9717 - loss: 1.0032 - val_accuracy: 0.9235 - val_loss: 1.0890 - learning_rate: 1.0000e-04
# Epoch 85/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 612ms/step - accuracy: 0.9823 - loss: 0.9172 - val_accuracy: 0.9293 - val_loss: 1.0313 - learning_rate: 1.0000e-04
# Epoch 86/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 33s 594ms/step - accuracy: 0.9888 - loss: 0.8627 - val_accuracy: 0.9467 - val_loss: 0.9335 - learning_rate: 1.0000e-04
# Epoch 87/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 592ms/step - accuracy: 0.9832 - loss: 0.8413 - val_accuracy: 0.9216 - val_loss: 0.9971 - learning_rate: 1.0000e-04
# Epoch 88/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 628ms/step - accuracy: 0.9750 - loss: 0.8056 - val_accuracy: 0.9428 - val_loss: 0.8975 - learning_rate: 1.0000e-04
# Epoch 89/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 569ms/step - accuracy: 0.9722 - loss: 0.7948 - val_accuracy: 0.9711 - val_loss: 0.7658 - learning_rate: 1.0000e-04
# Epoch 90/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 573ms/step - accuracy: 0.9727 - loss: 0.7775 - val_accuracy: 0.9499 - val_loss: 0.8054 - learning_rate: 1.0000e-04
# Epoch 91/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 30s 570ms/step - accuracy: 0.9676 - loss: 0.7496 - val_accuracy: 0.9846 - val_loss: 0.6668 - learning_rate: 1.0000e-04
# Epoch 92/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 31s 580ms/step - accuracy: 0.9792 - loss: 0.6995 - val_accuracy: 0.9486 - val_loss: 0.7701 - learning_rate: 1.0000e-04
# Epoch 93/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 602ms/step - accuracy: 0.9880 - loss: 0.6321 - val_accuracy: 0.9846 - val_loss: 0.5996 - learning_rate: 1.0000e-04
# Epoch 94/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 580ms/step - accuracy: 0.9750 - loss: 0.6345 - val_accuracy: 0.9396 - val_loss: 0.7105 - learning_rate: 1.0000e-04
# Epoch 95/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 595ms/step - accuracy: 0.9720 - loss: 0.6365 - val_accuracy: 0.8445 - val_loss: 1.0381 - learning_rate: 1.0000e-04
# Epoch 96/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 591ms/step - accuracy: 0.9638 - loss: 0.6246 - val_accuracy: 0.9833 - val_loss: 0.5311 - learning_rate: 1.0000e-04
# Epoch 97/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 614ms/step - accuracy: 0.9803 - loss: 0.5455 - val_accuracy: 0.9916 - val_loss: 0.4886 - learning_rate: 1.0000e-04
# Epoch 98/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 40s 596ms/step - accuracy: 0.9725 - loss: 0.5489 - val_accuracy: 0.8991 - val_loss: 0.7632 - learning_rate: 1.0000e-04
# Epoch 99/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 32s 577ms/step - accuracy: 0.9571 - loss: 0.5843 - val_accuracy: 0.9569 - val_loss: 0.5545 - learning_rate: 1.0000e-04
# Epoch 100/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 598ms/step - accuracy: 0.9669 - loss: 0.5376 - val_accuracy: 0.8522 - val_loss: 0.9180 - learning_rate: 1.0000e-04

# %%
# Plot accuracy and loss
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(loc='upper left')

plt.show()

# %%
# Evaluate model
predictions = model.predict(test_images)
predicted_classes = np.argmax(predictions, axis=1)

# Classification report and confusion matrix
print(classification_report(test_labels_encoded, predicted_classes, target_names=encoder.classes_))
cm = confusion_matrix(test_labels_encoded, predicted_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=encoder.classes_, yticklabels=encoder.classes_)
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 11s 160ms/step
#               precision    recall  f1-score   support
#
#      Aitinyo       0.99      0.99      0.99       374
#      Ayamaru       1.00      0.99      0.99       311
#       Kokoda       1.00      1.00      1.00       302
#          Moi       0.98      0.99      0.99       330
#        Tehit       1.00      0.98      0.99       239
#
#     accuracy                           0.99      1556
#    macro avg       0.99      0.99      0.99      1556
# weighted avg       0.99      0.99      0.99      1556
